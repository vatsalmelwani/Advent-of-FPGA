# %%
z=0
with open("inp.txt", "r") as f:
    m = 0
    for line in f:
        line = line.strip()
        a = (int(line[1:]))%100
        x = int(line[1:])
        b = str(line[0])
        if (b=='R'):
            if(m+a >= 100):
                z+=1
            m = (m + a)%100
        elif (b=='L'):
            if(m-a <= 0 and m!=0):
                z+=1
            m = (m + 100 - a)%100
        z += x//100
        # print("....")
        # print(line)
        # print(m)
        # print(z)
        # print(".....")
        # print()
print(z)
# Out:
# 6664

# %%
z=0
with open("inp.txt", "r") as f:
    m = 0
    for line in f:
        line = line.strip()
        a = (int(line[1:]))%100
        x = int(line[1:])
        b = str(line[0])
        print(format(x, '03X'))
# print(z)
# Out:
# 008
# 01C
# 02B
# 01D
# 003
# 01D
# 018
# 00C
# 016
# 005
# 005
# 02B
# 008
# 01E
# 020
# 028
# 00E
# 027
# 003
# 017
# 009
# 021
# 001
# 015
# 024
# 005
# 02C
# 001
# 008
# 004
# 018
# 01F
# 003
# 026
# 00A
# 022
# 014
# 006
# 00E
# 01F
# 032
# 02B
# 010
# 012
# 008
# 008
# 015
# 018
# 025
# 027
# 04E
# 04F
# 006
# 014
# 04E
# 007
# 00C
# 011
# 003
# 061
# 011
# 041
# 002
# 038
# 001
# 05D
# 03D
# 027
# 041
# 035
# 052
# 021
# 021
# 029
# 029
# 002
# 062
# 03F
# 037
# 00F
# 037
# 044
# 00D
# 00D
# 04D
# 041
# 00E
# 028
# 053
# 039
# 051
# 043
# 034
# 056
# 056
# 031
# 033
# 00E
# 03C
# 01A
# 007
# 05B
# 05B
# 04E
# 001
# 034
# 02E
# 036
# 01A
# 013
# 00F
# 153
# 041
# 060
# 031
# 045
# 033
# 01D
# 1C8
# 165
# 087
# 04E
# 056
# 048
# 056
# 046
# 03F
# 007
# 05C
# 008
# 057
# 013
# 015
# 04A
# 055
# 041
# 013
# 00B
# 05F
# 28E
# 026
# 027
# 05E
# 02F
# 05C
# 05C
# 014
# 035
# 043
# 006
# 05E
# 018
# 03F
# 105
# 123
# 061
# 00A
# 01B
# 045
# 331
# 051
# 005
# 049
# 05E
# 062
# 2DD
# ...
